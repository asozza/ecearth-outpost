# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
from ecpost.core.graphics.timeseries import timeseries

# %%
timeseries(expname='pi00', startyear=2000, endyear=2300, varname='thetao', avetype='moving')
# Out:
# 2025-12-01 20:08:13,953 - INFO - File to be loaded /Users/asozza/Documents/work/ecearth/runs/pi00/post/thetao_pi00_2000-2300_timeseries_plain.nc
# 2025-12-01 20:08:14,273 - INFO - Averaged data found.
