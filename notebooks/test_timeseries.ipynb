# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
from ecpost.core.graphics.timeseries import timeseries

# %%
timeseries(expname='cs00', startyear=2000, endyear=4000, varname='thetao', avetype='moving', label='COLD-START')
timeseries(expname='cw00', startyear=2000, endyear=3800, varname='thetao', avetype='moving', label='WOA13')
plt.legend(
    bbox_to_anchor=(0.98, 0.98),  # x, y coordinates for legend placement
    loc='upper right',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
# Out:
# 2025-12-02 13:26:40,457 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cs00/post/thetao_cs00_2000-4000_timeseries_plain.nc
# 2025-12-02 13:26:40,515 - INFO - Averaged data found.
# 2025-12-02 13:26:40,816 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cw00/post/thetao_cw00_2000-3800_timeseries_plain.nc
# 2025-12-02 13:26:40,869 - INFO - Averaged data found.
