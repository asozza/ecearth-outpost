# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
from ecpost.core.graphics.timeseries import timeseries

# %%
timeseries(expname='cs00', startyear=1990, endyear=5999, varname='thetao', avetype='moving', label='CS1850')
timeseries(expname='cs90', startyear=1990, endyear=4999, varname='thetao', avetype='moving', label='CS1990')
timeseries(expname='cw00', startyear=1990, endyear=5999, varname='thetao', avetype='moving', label='WOA13')
plt.legend(
    bbox_to_anchor=(0.98, 0.98),  # x, y coordinates for legend placement
    loc='upper right',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.title('Coupled Mode')
# Out:
# 2026-01-07 13:11:57,248 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cs00/post/thetao_cs00_1990-5999_timeseries_plain.nc
# 2026-01-07 13:11:57,341 - INFO - Averaged data found.
# 2026-01-07 13:11:57,942 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cs90/post/thetao_cs90_1990-4999_timeseries_plain.nc
# 2026-01-07 13:11:58,013 - INFO - Averaged data found.
# 2026-01-07 13:11:58,454 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cw00/post/thetao_cw00_1990-5999_timeseries_plain.nc
# 2026-01-07 13:11:58,547 - INFO - Averaged data found.
# Text(0.5, 1.0, 'Coupled Mode')

# %%
timeseries(expname='os00', startyear=1990, endyear=4999, varname='thetao', avetype='moving', label='COLD-START')
timeseries(expname='ow00', startyear=1990, endyear=4999, varname='thetao', avetype='moving', label='WOA13')
plt.legend(
    bbox_to_anchor=(0.98, 0.98),  # x, y coordinates for legend placement
    loc='upper right',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.title("OMIP Mode")
# Out:
# 2025-12-05 10:41:41,876 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/os00/post/thetao_os00_1990-4999_timeseries_plain.nc
# 2025-12-05 10:41:41,957 - INFO - Averaged data found.
# 2025-12-05 10:41:41,961 - INFO - {'longest': {'file': '/ec/res4/scratch/itas/ece4/os00/post/thetao_os00_1990-4999_timeseries_plain.nc', 'start': 1990, 'end': 4999, 'span': 3010}, 'contained': [], 'partial': [], 'disjoint': []}
# 2025-12-05 10:41:41,961 - INFO - Longest merged file: /ec/res4/scratch/itas/ece4/os00/post/thetao_os00_1990-4999_timeseries_plain.nc [1990-4999]
# 2025-12-05 10:41:41,962 - INFO - Fully contained files (candidate for deletion): []
# 2025-12-05 10:41:41,962 - INFO - Partially overlapping files: []
# 2025-12-05 10:41:41,962 - INFO - Disjoint files: []
# 2025-12-05 10:41:41,962 - INFO - Dry run enabled. No files were deleted.
# 2025-12-05 10:41:41,963 - INFO - Merged file cleanup summary:
# ...

# %%
# 3 plot by layers (how to define boundaries of the pycnocline? based on sigma levels.) And also divided into basins?

# %%
# accelerated runs

timeseries(expname='csa0', startyear=1990, endyear=2039, varname='thetao', avetype='moving', label='csa0')
timeseries(expname='csa1', startyear=1990, endyear=2039, varname='thetao', avetype='moving', label='csa1')
timeseries(expname='csa2', startyear=1990, endyear=2029, varname='thetao', avetype='moving', label='csa2')
plt.legend(
    bbox_to_anchor=(0.98, 0.98),  # x, y coordinates for legend placement
    loc='upper right',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.title('Accelerated Runs')
# Out:
# 2026-01-04 15:42:05,540 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/csa0/post/thetao_csa0_1990-2039_timeseries_plain.nc
# 2026-01-04 15:42:06,293 - INFO - Averaged data not found. Creating new file ...
# 2026-01-04 15:42:06,296 - INFO - No merged files found.
# 2026-01-04 15:42:06,296 - INFO - Processing year: 1990
# 2026-01-04 15:42:06,334 - INFO - Data available in the range 1990-1990.
# 2026-01-04 15:42:19,661 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/csa0/post/thetao_csa0_1990-1990_timeseries_plain.nc
# 2026-01-04 15:42:23,123 - INFO - Processing year: 1991
# 2026-01-04 15:42:23,141 - INFO - Data available in the range 1991-1991.
# 2026-01-04 15:42:23,262 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/csa0/post/thetao_csa0_1991-1991_timeseries_plain.nc
# 2026-01-04 15:42:24,390 - INFO - Processing year: 1992
# 2026-01-04 15:42:24,514 - INFO - Data available in the range 1992-1992.
# ...
