# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
from ecpost.core.utils.postreader import postreader_nemo

expname='cs00'
startyear=1990
endyear=2020
varname='thetao'
diagname='timeseries'
mode='plain'
orca='ORCA2'
metric='base'
refinfo = {
    'expname': 'cs00',
    'startyear': 6949,
    'endyear': 6999
}
data0 = postreader_nemo(expname=expname, startyear=startyear, endyear=endyear, varname=varname, diagname=diagname, mode=mode, metric=metric, refinfo=refinfo, orca=orca)
# Out:
# 2026-04-23 16:00:16,089 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cs00/post/cs00_1990-2020_thetao_timeseries_plain.nc
# 2026-04-23 16:00:16,253 - INFO - Averaged data found.

# %%
expname='FE01'
startyear=1990
endyear=2239
varname='thetao'
diagname='timeseries'
mode='plain'
orca='ORCA2'
data1 = postreader_nemo(expname=expname, startyear=startyear, endyear=endyear, varname=varname, diagname=diagname, mode=mode, orca=orca)
# Out:
# 2026-03-26 11:23:26,686 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/FE01/post/thetao_FE01_1990-2239_timeseries_plain.nc
# 2026-03-26 11:23:26,764 - INFO - Averaged data found.

# %%
from ecpost.core.io.postreader import postreader_nemo

expname='cs00'
startyear=5949
endyear=5959
varname='thetao'
diagname='profile'
mode='global'
orca='ORCA2'
metric='diff'
refinfo = {
    'expname': 'cs00',
    'startyear': 6949,
    'endyear': 6999
}
data1 = postreader_nemo(expname=expname, startyear=startyear, endyear=endyear, varname=varname, diagname=diagname, mode=mode, metric=metric, refinfo=refinfo, orca=orca)
# Out:
# 2026-04-23 14:39:24,946 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cs00/post/cs00_6949-6999_thetao_field_global.nc
# 2026-04-23 14:39:25,153 - INFO - Reference data found.
# 2026-04-23 14:39:25,155 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cs00/post/cs00_5949-5959_thetao_profile_global_diff.nc
# 2026-04-23 14:39:25,156 - INFO - Averaged data not found. Creating new file ...
# 2026-04-23 14:39:25,159 - INFO - {'longest': {'file': '/ec/res4/scratch/itas/ece4/cs00/post/cs00_1990-2020_thetao_profile_global_diff.nc', 'start': 1990, 'end': 2020, 'span': 31}, 'contained': [], 'partial': [], 'disjoint': []}
# 2026-04-23 14:39:25,160 - INFO - Usable merged blocks:
# 2026-04-23 14:39:25,160 - INFO - Processing year: 5949
# 2026-04-23 14:39:25,188 - INFO - Data available in the range 5949-5949.
# 2026-04-23 14:39:25,439 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cs00/post/cs00_5949-5949_thetao_profile_global_diff.nc
# ...

# %%
data0.thetao.plot()
data1.thetao.plot()
