# %%
from ecpost.core.utils import catalogue

# %%
from ecpost.core.utils.config import Config
cfg = Config()
cfg

# %%
cfg.base_path
# Out:
# '/ec/res4/scratch/itas/ece4/cs00'

# %%
cfg.src_path
# Out:
# '/ec/res4/hpcperm/itas/src/gitlab/ecearth4-v4.1.3/sources'
