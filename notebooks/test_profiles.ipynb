# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
from ecpost.core.graphics.profile import plot_profile

# %%
plot_profile(expname='cw00', startyear=6900, endyear=6999, varname='so', label='CS1850')
plot_profile(expname='cs00', startyear=6900, endyear=6999, varname='so', label='WOA13')
plt.legend(
    bbox_to_anchor=(0.98, 0.98),  # x, y coordinates for legend placement
    loc='upper right',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.title('Salinity')
# Out:
# 2026-06-04 14:37:59,073 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cw00/post/cw00_6900-6999_so_profile_global.nc
# 2026-06-04 14:37:59,074 - INFO - Averaged data not found. Creating new file ...
# 2026-06-04 14:37:59,077 - INFO - No merged files found.
# 2026-06-04 14:37:59,077 - INFO - Processing year: 6900
# 2026-06-04 14:37:59,079 - INFO - Data available in the range 6900-6900.
# 2026-06-04 14:37:59,507 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cw00/post/cw00_6900-6900_so_profile_global.nc
# 2026-06-04 14:38:00,563 - INFO - Processing year: 6901
# 2026-06-04 14:38:00,566 - INFO - Data available in the range 6901-6901.
# 2026-06-04 14:38:00,714 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cw00/post/cw00_6901-6901_so_profile_global.nc
# 2026-06-04 14:38:01,638 - INFO - Processing year: 6902
# 2026-06-04 14:38:01,640 - INFO - Data available in the range 6902-6902.
# ...

# %%
plot_profile(expname='cw00', startyear=6900, endyear=6999, varname='thetao', label='CS1850')
plot_profile(expname='cs00', startyear=6900, endyear=6999, varname='thetao', label='WOA13')
plt.legend(
    bbox_to_anchor=(0.98, 0.98),  # x, y coordinates for legend placement
    loc='upper right',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.title('Temperature')
# Out:
# 2026-06-04 14:30:42,043 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cw00/post/cw00_6900-6999_thetao_profile_global.nc
# 2026-06-04 14:30:43,284 - INFO - Averaged data not found. Creating new file ...
# 2026-06-04 14:30:43,296 - INFO - No merged files found.
# 2026-06-04 14:30:43,296 - INFO - Processing year: 6900
# 2026-06-04 14:30:43,328 - INFO - Data available in the range 6900-6900.
# 2026-06-04 14:30:51,806 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cw00/post/cw00_6900-6900_thetao_profile_global.nc
# 2026-06-04 14:30:53,259 - INFO - Processing year: 6901
# 2026-06-04 14:30:53,296 - INFO - Data available in the range 6901-6901.
# 2026-06-04 14:30:53,447 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cw00/post/cw00_6901-6901_thetao_profile_global.nc
# 2026-06-04 14:30:54,484 - INFO - Processing year: 6902
# 2026-06-04 14:30:54,514 - INFO - Data available in the range 6902-6902.
# ...

# %%
profile(expname='FE01', startyear=2230, endyear=2239, varname='thetao', label='FE01')
profile(expname='cs00', startyear=3730, endyear=3739, varname='thetao', label='cs00')
plt.legend(
    bbox_to_anchor=(0.98, 0.98),  # x, y coordinates for legend placement
    loc='upper right',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.title('Temperature')
# Out:
# 2026-02-24 12:44:12,035 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/FE01/post/thetao_FE01_2230-2239_profile_global.nc
# 2026-02-24 12:44:12,042 - INFO - Averaged data found.
# 2026-02-24 12:44:12,053 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cs00/post/thetao_cs00_3730-3739_profile_global.nc
# 2026-02-24 12:44:12,054 - INFO - Averaged data not found. Creating new file ...
# 2026-02-24 12:44:12,057 - INFO - No merged files found.
# 2026-02-24 12:44:12,058 - INFO - Processing year: 3730
# 2026-02-24 12:44:12,060 - INFO - Data available in the range 3730-3730.
# 2026-02-24 12:44:12,162 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cs00/post/thetao_cs00_3730-3730_profile_global.nc
# 2026-02-24 12:44:12,305 - INFO - Processing year: 3731
# 2026-02-24 12:44:12,307 - INFO - Data available in the range 3731-3731.
# 2026-02-24 12:44:12,407 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cs00/post/thetao_cs00_3731-3731_profile_global.nc
# ...

# %%
profile_diff(expname1='FE01', startyear1=2230, endyear1=2239, expname2='cs00', startyear2=3730, endyear2=3739, varname='thetao', label='FE01')
plt.axvline(x=0, color='black', linestyle='--')
# Out:
# 2026-02-24 12:58:13,930 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/FE01/post/thetao_FE01_2230-2239_profile_global.nc
# 2026-02-24 12:58:14,191 - INFO - Averaged data found.
# 2026-02-24 12:58:14,197 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cs00/post/thetao_cs00_3730-3739_profile_global.nc
# 2026-02-24 12:58:14,203 - INFO - Averaged data found.
