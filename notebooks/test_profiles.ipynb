# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
from ecpost.core.graphics.profile import profile

# %%
profile(expname='cs00', startyear=1990, endyear=6999, varname='thetao', label='CS1850')
plt.legend(
    bbox_to_anchor=(0.98, 0.98),  # x, y coordinates for legend placement
    loc='upper right',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.title('Temperature')
# Out:
# 2026-01-20 15:30:46,666 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cs00/post/thetao_cs00_1990-6999_timeseries_plain.nc
# 2026-01-20 15:30:46,999 - INFO - Averaged data found.
# 2026-01-20 15:30:47,722 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cw00/post/thetao_cw00_1990-6999_timeseries_plain.nc
# 2026-01-20 15:30:47,857 - INFO - Averaged data found.
# Text(0.5, 1.0, 'Global Temperature')
