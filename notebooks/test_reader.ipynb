# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
from ecpost.core.io.postreader import postreader_nemo

# %%
data = postreader_nemo(expname='pi00', startyear=2000, endyear=2300, varname='thetao', diagname='timeseries', format='plain', replace=False)
# Out:
# 2025-12-01 09:40:03,761 - INFO - File to be loaded /Users/asozza/Documents/work/ecearth/runs/pi00/post/thetao_pi00_2000-2300_timeseries_plain.nc
# 2025-12-01 09:40:04,139 - INFO - Averaged data found.

# %%
data['thetao'].plot()
