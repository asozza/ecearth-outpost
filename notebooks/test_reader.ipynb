# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
import ecpost.core as eoc

# %%
help(eoc)
# Out:
# Help on package ecpost.core in ecpost:
#
# NAME
#     ecpost.core - core module
#
# PACKAGE CONTENTS
#     catalogue
#     config
#     io
#     io-post
#
# FILE
#     /Users/asozza/Documents/github/ecearth-outpost/ecpost/core/__init__.py

# %%
from ecpost.core import io
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from ecpost.core import io
#
# File ~/Documents/github/ecearth-outpost/ecpost/core/io.py:19
#      16 import dask
#      18 from ecpost.core import config
# ---> 19 from ecpost.core import catalogue
#      21 # dask optimization
#      22 #dask.config.set({'array.optimize_blockwise': True})
#      23
#      24 ##########################################################################################
#      25 # Detector of axis candidates
#      27 axis_candidates = {
#      28     'time': ['time_counter', 'time', 't'],
#      29     'x': ['x', 'x_grid_T', 'x_grid_U', 'x_grid_V', 'x_grid_W', 'lon', 'longitude', 'nav_lon'],
#      30     'y': ['y', 'y_grid_T', 'y_grid_U', 'y_grid_V', 'y_grid_W', 'lat', 'latitude', 'nav_lat'],
#      31     'z': ['deptht', 'depthu', 'depthv', 'depthw', 'depth', 'z', 'lev', 'nav_lev']
#      32 }
#
# File ~/Documents/github/ecearth-outpost/ecpost/core/catalogue.py:14
#       4 """
#       5 EC-Earth catalogue
#       6 Dictionaries of variables, coordinates and diagnostics' features
#    (...)      9 Date: Nov 2025
#      10 """
#      12 import gsw  # Gibbs SeaWater library for oceanographic calculations
# ---> 14 from outpost.regrid import regrid_U_to_T, regrid_V_to_T, regrid_W_to_T
#      16 def _density(thetao, so):
#      17     """ Potential density """
#
# ModuleNotFoundError: No module named 'outpost'

# %%
data = reader_nemo_field(expname='pi00', startyear=2000, endyear=2000, varname='thetao')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 import ecpost.core as eoc
# ----> 2 from eoc import reader_nemo_field
#       4 data = reader_nemo_field(expname='pi00', startyear=2000, endyear=2000, varname='thetao')
#
# ModuleNotFoundError: No module named 'eoc'

# %%
data = ecpost.core.io.reader_nemo_field(expname='pi00', startyear=2000, endyear=2000, varname='thetao')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = ecpost.core.io.reader_nemo_field(expname='pi00', startyear=2000, endyear=2000, varname='thetao')
#
# NameError: name 'ecpost' is not defined
