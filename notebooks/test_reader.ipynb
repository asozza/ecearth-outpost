# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
from ecpost.core.io.postreader import postreader_nemo

# %%
data = postreader_nemo(expname='pi01', startyear=1990, endyear=2090, varname='thetao', diagname='timeseries', format='plain', replace=False, cleanup=True)
# Out:
# 2025-12-04 18:03:41,382 - INFO - File to be loaded /Users/asozza/Documents/work/ecearth/runs/pi01/post/thetao_pi01_1990-2080_timeseries_plain.nc
# 2025-12-04 18:03:41,640 - INFO - Averaged data found.

# %%
data = postreader_nemo(expname='pi00', startyear=2000, endyear=2300, varname='thetao', diagname='timeseries', format='plain', replace=False)

# %%
data['thetao'].plot()

# %%
data = postreader_nemo(expname='cw00', startyear=2000, endyear=3800, varname='thetao', diagname='timeseries', format='plain', replace=False)
# Out:
# 2025-12-02 11:24:15,298 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cw00/post/thetao_cw00_2000-3800_timeseries_plain.nc
# 2025-12-02 11:24:15,655 - INFO - Averaged data not found. Creating new file ...
# 2025-12-02 11:24:15,656 - INFO - Processing year 2000
# 2025-12-02 11:24:15,660 - INFO - Data available in the range 2000-2000.
# 2025-12-02 11:24:20,761 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cw00/post/thetao_cw00_2000-2000_timeseries_plain.nc
# 2025-12-02 11:24:25,426 - INFO - Processing year 2001
# 2025-12-02 11:24:25,596 - INFO - Data available in the range 2001-2001.
# 2025-12-02 11:24:25,772 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cw00/post/thetao_cw00_2001-2001_timeseries_plain.nc
# 2025-12-02 11:24:27,681 - INFO - Processing year 2002
# 2025-12-02 11:24:27,701 - INFO - Data available in the range 2002-2002.
# 2025-12-02 11:24:27,858 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cw00/post/thetao_cw00_2002-2002_timeseries_plain.nc
# ...

# %%
data['thetao'].plot()
