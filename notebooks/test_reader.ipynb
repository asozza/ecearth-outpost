# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
import ecpost.core as eoc

# %%
help(eoc)
# Out:
# Help on package ecpost.core in ecpost:
#
# NAME
#     ecpost.core - core module
#
# PACKAGE CONTENTS
#     catalogue
#     config
#     domain
#     io
#     io-post
#     regrid
#
# FILE
#     /Users/asozza/Documents/github/ecearth-outpost/ecpost/core/__init__.py

# %%
from ecpost.core import io

# %%
help(io)
# Out:
# Help on module ecpost.core.io in ecpost.core:
#
# NAME
#     ecpost.core.io - I/O module
#
# DESCRIPTION
#     Author: Alessandro Sozza (CNR-ISAC)
#     Date: Nov 2025
#
# FUNCTIONS
#     detect_axis(ds, axis_type, where='dims', verbose=False)
#         Detects the name of a given axis (time/x/y/z) in an xarray Dataset or DataArray.
#
#         Args:
#             ds : xarray.Dataset or xarray.DataArray
#                 The object to inspect.
#             axis_type : str
#                 One of ['time', 'x', 'y', 'z'].
#             where : str
#                 Search in 'dims', 'coords' or 'data_vars'.
#             verbose : bool
#                 If True, prints messages about detection.
#
#         Returns:
#             str or None : the name of the detected axis, or None if not found.
#
#     preproc_nemo(data, grid)
#         General preprocessing routine for NEMO data based on grid type
#
#         Args:
#         data: dataset
#         grid: gridname [T, U, V, W]
#
# ...

# %%
import os
os.getcwd()
# Out:
# '/Users/asozza/Documents/github/ecearth-outpost/notebooks'

# %%
from ecpost.core import config

# %%
config.load_config()
# Out:
# {'darwin': {'base_path': '/Users/asozza/Documents/work/ecearth/runs',
#   'src_path': '/Users/asozza/Documents/work/ecearth/src',
#   'data_path': '/Users/asozza/Documents/work/ecearth/data'},
#  'linux': {'base_path': '/ec/res4/scratch/itas/ece4',
#   'src_path': '/ec/res4/hpcperm/itas/src/',
#   'data_path': '/ec/res4/hpcperm/itas/data/ece-4-database'}}

# %%
dirs = config.folders(expname='pi00')

# %%
data = io.reader_nemo(expname='pi00', startyear=2000, endyear=2000)
# Out:
# 2025-11-29 17:57:17,836 - INFO - Data available in the range 2000-2000.

# %%
data = io.reader_nemo_field(expname='pi00', startyear=2000, endyear=2000, varname='thetao')
# Out:
# 2025-11-29 17:57:26,856 - INFO - Data available in the range 2000-2000.
