# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt

# %%
from ecpost.core.graphics.timeseries import plot_timeseries

# %%
#timeseries(expname='cs00', startyear=1990, endyear=2029, varname='thetao', label='cs00')
#timeseries(expname='csa0', startyear=1990, endyear=2039, varname='thetao', label='csa0')
#timeseries(expname='xb00', startyear=1990, endyear=2009, varname='thetao', label='xb00')
plot_timeseries(expname='xa00', startyear=1990, endyear=2080, varname='thetao', label='xa00')
plot_timeseries(expname='qa00', startyear=1990, endyear=2080, varname='thetao', label='qa00')
#plot_timeseries(expname='ya00', startyear=1990, endyear=2060, varname='thetao', label='ya00')
plt.legend(bbox_to_anchor=(0.98, 0.98), loc='upper right', borderaxespad=0)
plt.title('Global Temperature')
# Out:
# 2026-07-28 09:03:11,860 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/xa00/post/xa00_1990-2080_thetao_timeseries_plain.nc
# 2026-07-28 09:03:18,349 - INFO - Averaged data found.
# 2026-07-28 09:03:18,789 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/qa00/post/qa00_1990-2080_thetao_timeseries_plain.nc
# 2026-07-28 09:03:18,823 - INFO - Averaged data found.
# Text(0.5, 1.0, 'Global Temperature')

# %%
timeseries(expname='cs00', startyear=1990, endyear=6999, varname='tos', avetype='moving', label='CS1850')
timeseries(expname='cw00', startyear=1990, endyear=6999, varname='tos', label='WOA13')
plt.legend(
    bbox_to_anchor=(0.98, 0.98),  # x, y coordinates for legend placement
    loc='upper right',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.title('Surface Temperature')
# Out:
# 2026-01-20 09:51:01,441 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cs00/post/tos_cs00_1990-6999_timeseries_plain.nc
# 2026-01-20 09:51:02,605 - INFO - Averaged data found.
# 2026-01-20 09:51:03,558 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cw00/post/tos_cw00_1990-6999_timeseries_plain.nc
# 2026-01-20 09:51:03,669 - INFO - Averaged data found.
# Text(0.5, 1.0, 'Surface Temperature')

# %%
timeseries(expname='cs00', startyear=1990, endyear=6999, varname='sbt', label='CS1850')
timeseries(expname='cw00', startyear=1990, endyear=6999, varname='sbt', label='WOA13')
plt.legend(
    bbox_to_anchor=(0.98, 0.98),  # x, y coordinates for legend placement
    loc='upper right',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.title('Bottom Temperature')
# Out:
# 2026-01-20 08:44:42,117 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cs00/post/sbt_cs00_1990-6999_timeseries_plain.nc
# 2026-01-20 08:44:42,487 - INFO - Averaged data found.
# 2026-01-20 08:44:43,426 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/cw00/post/sbt_cw00_1990-6999_timeseries_plain.nc
# 2026-01-20 08:44:43,594 - INFO - Averaged data found.
# Text(0.5, 1.0, 'Bottom Temperature')

# %%
timeseries(expname='cs00', startyear=1990, endyear=6999, varname='zos', label='CS1850')
timeseries(expname='cw00', startyear=1990, endyear=6999, varname='zos', label='WOA13')
#timeseries(expname='os00', startyear=1990, endyear=3010, varname='zos', label='OS1850')
plt.legend(
    bbox_to_anchor=(0.02, 0.98),  # x, y coordinates for legend placement
    loc='upper left',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.title('Surface Height')
# Out:
# 2026-01-22 19:10:39,934 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/os00/post/zos_os00_1990-3010_timeseries_plain.nc
# 2026-01-22 19:10:39,961 - INFO - Averaged data found.
# Text(0.5, 1.0, 'Surface Height')

# %%
# 3 plot by layers (how to define boundaries of the pycnocline? based on sigma levels.) And also divided into basins?

# %%
# accelerated runs

timeseries(expname='csa0', startyear=1990, endyear=2079, varname='thetao', avetype='moving', label='csa0')
timeseries(expname='csa1', startyear=1990, endyear=2009, varname='thetao', avetype='moving', label='csa1')
timeseries(expname='csa2', startyear=1990, endyear=2029, varname='thetao', avetype='moving', label='csa2')
timeseries(expname='csa3', startyear=1990, endyear=2019, varname='thetao', avetype='moving', label='csa3')
timeseries(expname='csa4', startyear=1990, endyear=2029, varname='thetao', avetype='moving', label='csa4')
plt.legend(
    bbox_to_anchor=(0.98, 0.98),  # x, y coordinates for legend placement
    loc='upper right',         # Location of the legend relative to bbox_to_anchor
    borderaxespad=0           # Padding between the legend and the plot
)
plt.title('Accelerated Runs')
# Out:
# 2026-01-20 15:36:39,340 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/csa0/post/thetao_csa0_1990-2079_timeseries_plain.nc
# 2026-01-20 15:36:39,341 - INFO - Averaged data not found. Creating new file ...
# 2026-01-20 15:36:39,345 - INFO - No merged files found.
# 2026-01-20 15:36:39,345 - INFO - Processing year: 1990
# 2026-01-20 15:36:39,379 - INFO - Data available in the range 1990-1990.
# 2026-01-20 15:36:39,529 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/csa0/post/thetao_csa0_1990-1990_timeseries_plain.nc
# 2026-01-20 15:36:41,354 - INFO - Processing year: 1991
# 2026-01-20 15:36:41,403 - INFO - Data available in the range 1991-1991.
# 2026-01-20 15:36:41,578 - INFO - File to be loaded /ec/res4/scratch/itas/ece4/csa0/post/thetao_csa0_1991-1991_timeseries_plain.nc
# 2026-01-20 15:36:42,874 - INFO - Processing year: 1992
# 2026-01-20 15:36:42,910 - INFO - Data available in the range 1992-1992.
# ...
