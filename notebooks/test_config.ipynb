# %%
from ecpost.core.utils import config

# %%
base_path = "/ec/res4/scratch/itas/ece4"
src_path = "/ec/res4/hpcperm/itas/src/"
data_path = "/ec/res4/hpcperm/itas/data/ece-4-database"

# %%
cfg = config.Config()

# %%
dirs = cfg.folders('cs00')

# %%
dirs
# Out:
# {'exp': '/ec/res4/scratch/itas/ece4/cs00',
#  'nemo': '/ec/res4/scratch/itas/ece4/cs00/output/nemo',
#  'oifs': '/ec/res4/scratch/itas/ece4/cs00/output/oifs',
#  'restart': '/ec/res4/scratch/itas/ece4/cs00/restart',
#  'log': '/ec/res4/scratch/itas/ece4/cs00/log',
#  'saveic': '/ec/res4/scratch/itas/ece4/cs00/saveic',
#  'post': '/ec/res4/scratch/itas/ece4/cs00/post',
#  'rebuild': '/ec/res4/hpcperm/itas/src/rebuild_nemo',
#  'domain': '/ec/res4/hpcperm/itas/data/ece-4-database/nemo/domain'}
